# %% [markdown]
# `-` imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 숙제2

# %%
df=pd.read_csv('https://raw.githubusercontent.com/guebin/DV2022/master/_notebooks/dv2022.csv')
df
# Out:
#      att  rep  mid  fin
# 0     65   45    0   10
# 1     95   30   60   10
# 2     65   85   15   20
# 3     55   35   35    5
# 4     80   60   55   70
# ..   ...  ...  ...  ...
# 195   55   70   40   95
# 196   65   85   25   85
# 197   85   85  100   10
# 198   80   65   35   60
# 199   50   95   45   85
#
# [200 rows x 4 columns]

# %% [markdown]
# # df 공부 1단계

# %% [markdown]
# ## 컨셉1: 클래스의 오브젝트 같은 느낌

# %%
df.fin #series
# Out:
# 0      10
# 1      10
# 2      20
# 3       5
# 4      70
#        ..
# 195    95
# 196    85
# 197    10
# 198    60
# 199    85
# Name: fin, Length: 200, dtype: int64

# %% [markdown]
# ## 컨셉2: 딕셔너리 + 알파 같은 느낌

# %%
dct = dict(df)
dct.keys(), df.keys() #key() 메서드를 통해 칼럼의 이름을 볼 수 있다,
# Out:
# (dict_keys(['att', 'rep', 'mid', 'fin']),
#  Index(['att', 'rep', 'mid', 'fin'], dtype='object'))

# %% [markdown]
# ### 열 인덱싱

# %% [markdown]
# #### 예시1

# %%
df['att'],dct['att'] #dct가 가능 하면 df도 가능
# Out:
# (0      65
#  1      95
#  2      65
#  3      55
#  4      80
#         ..
#  195    55
#  196    65
#  197    85
#  198    80
#  199    50
#  Name: att, Length: 200, dtype: int64,
#  0      65
#  1      95
#  2      65
#  3      55
#  4      80
#         ..
#  195    55
#  196    65
#  197    85
#  198    80
#  199    50
#  Name: att, Length: 200, dtype: int64)

# %% [markdown]
# #### 예시2

# %%
df.get('att'), dct.get('att') ##dct가 가능 하면 df도 가능 2
# Out:
# (0      65
#  1      95
#  2      65
#  3      55
#  4      80
#         ..
#  195    55
#  196    65
#  197    85
#  198    80
#  199    50
#  Name: att, Length: 200, dtype: int64,
#  0      65
#  1      95
#  2      65
#  3      55
#  4      80
#         ..
#  195    55
#  196    65
#  197    85
#  198    80
#  199    50
#  Name: att, Length: 200, dtype: int64)

# %% [markdown]
# #### 예시3

# %%
dct.get(['att','rep'])  #딕셔너리는 리스트 타입의 호출을 받을 수 없다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 dct.get(['att','rep'])
#
# TypeError: unhashable type: 'list'

# %%
df.get(['att','rep']) #df는 가능하다 3
# Out:
#      att  rep
# 0     65   45
# 1     95   30
# 2     65   85
# 3     55   35
# 4     80   60
# ..   ...  ...
# 195   55   70
# 196   65   85
# 197   85   85
# 198   80   65
# 199   50   95
#
# [200 rows x 2 columns]

# %% [markdown]
# #### 예시4

# %%
dct[['att','rep']] #리스트로 인덱싱 할 수 없다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 dct[['att','rep']]
#
# TypeError: unhashable type: 'list'

# %%
df[['att','rep']] #차원 유지
# Out:
#      att  rep
# 0     65   45
# 1     95   30
# 2     65   85
# 3     55   35
# 4     80   60
# ..   ...  ...
# 195   55   70
# 196   65   85
# 197   85   85
# 198   80   65
# 199   50   95
#
# [200 rows x 2 columns]

# %% [markdown]
# ### 행 인덱싱

# %% [markdown]
# #### 예시5

# %%
dct[:5] #스트라이딩을 통한 인덱싱 불가
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 dct[:5]
#
# TypeError: unhashable type: 'slice'

# %%
df[:5] #스트라이딩을 통한 인덱싱 가능
# Out:
#    att  rep  mid  fin
# 0   65   45    0   10
# 1   95   30   60   10
# 2   65   85   15   20
# 3   55   35   35    5
# 4   80   60   55   70

# %% [markdown]
# ## 컨셉3: 넘파이 어레이의 느낌

# %% [markdown]
# ### 행 인덱싱

# %% [markdown]
# #### 컨셉3: `df.iloc`은 넘파이 어레이처럼 생각 가능하다. 즉 아래의 arr과 같은 넘파이 어레이로 생각 가능하다.

# %% [markdown]
# #### 예시1 단일레이블

# %%
arr= np.array(df)

# %%
arr[0,:]
arr[0,]
arr[0]
# Out:
# array([65, 45,  0, 10], dtype=int64)

# %%
df.iloc[0,:]
df.iloc[0,]
df.iloc[0] #series가 출력된다.
# Out:
# att    65
# rep    45
# mid     0
# fin    10
# Name: 0, dtype: int64

# %%
df.iloc[0,:] #차원을 유지하고싶다면 df.iloc[[0]:,]
# Out:
# att    65
# rep    45
# mid     0
# fin    10
# Name: 0, dtype: int64

# %% [markdown]
# #### 예시2: 레이블의 리스트

# %%
arr[[0,1,2],:]
arr[[0,1,2],]
arr[[0,1,2]]
# Out:
# array([[65, 45,  0, 10],
#        [95, 30, 60, 10],
#        [65, 85, 15, 20]], dtype=int64)

# %%
df.iloc[[0,1,2],:]
df.iloc[[0,1,2],]
df.iloc[[0,1,2]]
# Out:
#    att  rep  mid  fin
# 0   65   45    0   10
# 1   95   30   60   10
# 2   65   85   15   20

# %% [markdown]
# #### 예시3: 슬라이싱

# %%
arr[0:3,:]
arr[0:3,]
arr[0:3]
# Out:
# array([[65, 45,  0, 10],
#        [95, 30, 60, 10],
#        [65, 85, 15, 20]], dtype=int64)

# %%
df.iloc[0:3,:]
df.iloc[0:3,]
df.iloc[0:3]
# Out:
#    att  rep  mid  fin
# 0   65   45    0   10
# 1   95   30   60   10
# 2   65   85   15   20

# %% [markdown]
# ### 열 인덱싱

# %% [markdown]
# #### 예시1 단일 레이블

# %%
df.iloc[:,0],arr[:,0]
# Out:
# (0      65
#  1      95
#  2      65
#  3      55
#  4      80
#         ..
#  195    55
#  196    65
#  197    85
#  198    80
#  199    50
#  Name: att, Length: 200, dtype: int64,
#  array([ 65,  95,  65,  55,  80,  75,  65,  60,  95,  90,  55,  95,  95,
#          50,  50,  95,  50,  65,  70,  90,  80,  55,  65,  70,  85,  90,
#         100,  80,  80,  55,  75,  80,  95,  95, 100, 100,  80,  70,  85,
#         100,  95,  75,  70,  50, 100,  75,  85,  80,  95,  65,  90,  65,
#          80,  95,  65,  90,  95, 100,  50,  90,  50,  80,  50,  70,  65,
#          60,  50,  60,  70,  75,  50,  85,  80,  55,  85,  65,  85,  60,
#          95,  85,  60, 100, 100,  55,  70,  70,  55, 100,  85, 100,  60,
#          65,  65,  75,  50,  75, 100,  90,  55,  75,  60,  85,  60,  70,
#          80,  65,  85, 100,  65,  85,  85,  85, 100,  95,  95,  55,  85,
#          75,  95,  85,  95, 100,  95,  95, 100,  55,  60,  85,  75,  55,
#          70,  80,  90,  90,  60,  90,  75,  60,  55,  70,  75,  90,  50,
#          55,  90,  75,  90,  85, 100,  55,  70,  90,  55, 100,  50, 100,
#          70,  85,  55,  75,  65,  70,  60, 100,  75,  90,  95,  90,  95,
#          55,  95,  65,  65,  90, 100,  70, 100,  50,  70,  70,  55,  55,
#          65,  90, 100,  70,  60,  70,  70,  65,  95,  50, 100,  55,  65,
#          55,  65,  85,  80,  50], dtype=int64))

# %% [markdown]
# #### 예시2 레이블의 리스트

# %%
df.iloc[:,[0,2]]
#arr[:,[0,2]]
# Out:
#      att  mid
# 0     65    0
# 1     95   60
# 2     65   15
# 3     55   35
# 4     80   55
# ..   ...  ...
# 195   55   40
# 196   65   25
# 197   85  100
# 198   80   35
# 199   50   45
#
# [200 rows x 2 columns]

# %% [markdown]
# #### 에시3 슬라이싱

# %%
df.iloc[:,0:3]
#arr[:0:3]
# Out:
#      att  rep  mid
# 0     65   45    0
# 1     95   30   60
# 2     65   85   15
# 3     55   35   35
# 4     80   60   55
# ..   ...  ...  ...
# 195   55   70   40
# 196   65   85   25
# 197   85   85  100
# 198   80   65   35
# 199   50   95   45
#
# [200 rows x 3 columns]

# %% [markdown]
# #### 행,열 인덱싱

# %%
df.iloc[::2,0:3] #짝수 행 인덱싕
# Out:
#      att  rep  mid
# 0     65   45    0
# 2     65   85   15
# 4     80   60   55
# 6     65   70   60
# 8     95   55   65
# ..   ...  ...  ...
# 190   95   35   40
# 192  100   40   80
# 194   65   40   65
# 196   65   85   25
# 198   80   65   35
#
# [100 rows x 3 columns]

# %% [markdown]
# ## 컨셉 4 데이타 프레임 느낌 by`.loc`

# %% [markdown]
# ### 행인덱싱

# %% [markdown]
# #### 예시1: 단일레이블

# %%
df.loc[0,:]
df.loc[0,]
df.loc[0]
# Out:
# att    65
# rep    45
# mid     0
# fin    10
# Name: 0, dtype: int64

# %% [markdown]
# #### 예시2: 레이블의 리스트

# %%
df.loc[[0,1,2],:]
df.loc[[0,1,2],]
df.loc[[0,1,2]]
# Out:
#    att  rep  mid  fin
# 0   65   45    0   10
# 1   95   30   60   10
# 2   65   85   15   20

# %% [markdown]
# #### 예시3 슬라이싱

# %%
df.loc[0:3,:]
df.loc[0:3,]
df.loc[0:3]
# Out:
#    att  rep  mid  fin
# 0   65   45    0   10
# 1   95   30   60   10
# 2   65   85   15   20
# 3   55   35   35    5

# %% [markdown]
# ### 열 인덱싱 by.loc

# %% [markdown]
# #### 예시1: 단일레이블

# %%
df.loc[:,'att']
# Out:
# 0      65
# 1      95
# 2      65
# 3      55
# 4      80
#        ..
# 195    55
# 196    65
# 197    85
# 198    80
# 199    50
# Name: att, Length: 200, dtype: int64

# %% [markdown]
# #### 예시2: 레이블의 리스트

# %%
df.loc[:,['att','mid']]
# Out:
#      att  mid
# 0     65    0
# 1     95   60
# 2     65   15
# 3     55   35
# 4     80   55
# ..   ...  ...
# 195   55   40
# 196   65   25
# 197   85  100
# 198   80   35
# 199   50   45
#
# [200 rows x 2 columns]

# %% [markdown]
# #### 예시3: 슬라이싱

# %%
df.loc[:,'att':'mid']
# Out:
#      att  rep  mid
# 0     65   45    0
# 1     95   30   60
# 2     65   85   15
# 3     55   35   35
# 4     80   60   55
# ..   ...  ...  ...
# 195   55   70   40
# 196   65   85   25
# 197   85   85  100
# 198   80   65   35
# 199   50   95   45
#
# [200 rows x 3 columns]

# %% [markdown]
# #### 행 열 콜라보

# %%
df.loc[::-1,'att':'mid']
# Out:
#      att  rep  mid
# 199   50   95   45
# 198   80   65   35
# 197   85   85  100
# 196   65   85   25
# 195   55   70   40
# ..   ...  ...  ...
# 4     80   60   55
# 3     55   35   35
# 2     65   85   15
# 1     95   30   60
# 0     65   45    0
#
# [200 rows x 3 columns]

# %%
df.loc[:,:'mid'] #록은 끝점을 포함한다
# Out:
#      att  rep  mid
# 0     65   45    0
# 1     95   30   60
# 2     65   85   15
# 3     55   35   35
# 4     80   60   55
# ..   ...  ...  ...
# 195   55   70   40
# 196   65   85   25
# 197   85   85  100
# 198   80   65   35
# 199   50   95   45
#
# [200 rows x 3 columns]

# %% [markdown]
# ### 자주 하는 실수

# %%
df['att'] #가능
#df.loc['att'] #불가능
df.loc[:,'att']
# Out:
# 0      65
# 1      95
# 2      65
# 3      55
# 4      80
#        ..
# 195    55
# 196    65
# 197    85
# 198    80
# 199    50
# Name: att, Length: 200, dtype: int64

# %% [markdown]
# # df 인덱싱 공부 2단계: 필터링(특정 조건에 맞는 row를 선택)

# %% [markdown]
# ## att> 90 and rep <50

# %% [markdown]
# ### `방법1`:qeury를 이용

# %%
df.query('att>90 and rep <50')
df.query('(att>90)&(rep<50)')
df.query('att>90 & rep<50')
# Out:
#      att  rep  mid  fin
# 1     95   30   60   10
# 12    95   35    0   25
# 48    95   45   35   80
# 56    95   25   95   90
# 78    95   45   90   35
# 107  100   30   60   65
# 112  100   35   70    0
# 113   95   45   55   65
# 163  100   25   10   20
# 174  100   40   40   15
# 176  100   30   70   70
# 184  100   30   30   85
# 190   95   35   40   95
# 192  100   40   80   80

# %% [markdown]
# ### `방법2`: [],iloc,loc

# %% [markdown]
# #### []

# %%
(df.att>90)&(df.rep<50) #시리즈가 나옴.
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
df[(df.att>90)&(df.rep<50)]
# Out:
#      att  rep  mid  fin
# 1     95   30   60   10
# 12    95   35    0   25
# 48    95   45   35   80
# 56    95   25   95   90
# 78    95   45   90   35
# 107  100   30   60   65
# 112  100   35   70    0
# 113   95   45   55   65
# 163  100   25   10   20
# 174  100   40   40   15
# 176  100   30   70   70
# 184  100   30   30   85
# 190   95   35   40   95
# 192  100   40   80   80

# %% [markdown]
# #### loc

# %%
df.loc[(df.att>90) & (df.rep <50)]
# Out:
#      att  rep  mid  fin
# 1     95   30   60   10
# 12    95   35    0   25
# 48    95   45   35   80
# 56    95   25   95   90
# 78    95   45   90   35
# 107  100   30   60   65
# 112  100   35   70    0
# 113   95   45   55   65
# 163  100   25   10   20
# 174  100   40   40   15
# 176  100   30   70   70
# 184  100   30   30   85
# 190   95   35   40   95
# 192  100   40   80   80

# %% [markdown]
# #### iloc

# %%
df.iloc[(df.att>90) & (df.rep <50)] #iloc은 시리즈를 안받는다
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 df.iloc[(df.att>90) & (df.rep <50)]
#
# File ~\anaconda3\envs\py39\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\envs\py39\lib\site-packages\pandas\core\indexing.py:1506, in _iLocIndexer._getitem_axis(self, key, axis)
#    1503     key = np.asarray(key)
#    1505 if com.is_bool_indexer(key):
# -> 1506     self._validate_key(key, axis)
#    1507     return self._getbool_axis(key, axis=axis)
#    1509 # a list of integers
#
# File ~\anaconda3\envs\py39\lib\site-packages\pandas\core\indexing.py:1347, in _iLocIndexer._validate_key(self, key, axis)
#    1345 if hasattr(key, "index") and isinstance(key.index, Index):
#    1346     if key.index.inferred_type == "integer":
# -> 1347         raise NotImplementedError(
#    1348             "iLocation based boolean "
#    1349             "indexing on an integer type "
#    1350             "is not available"
#    1351         )
#    1352     raise ValueError(
#    1353         "iLocation based boolean indexing cannot use "
#    1354         "an indexable as a mask"
#    1355     )
#    1356 return
#
# NotImplementedError: iLocation based boolean indexing on an integer type is not available

# %%
df.iloc[list((df.att > 90)& (df.rep <50))] #리스트화 해줘야 받는다
# Out:
#      att  rep  mid  fin
# 1     95   30   60   10
# 12    95   35    0   25
# 48    95   45   35   80
# 56    95   25   95   90
# 78    95   45   90   35
# 107  100   30   60   65
# 112  100   35   70    0
# 113   95   45   55   65
# 163  100   25   10   20
# 174  100   40   40   15
# 176  100   30   70   70
# 184  100   30   30   85
# 190   95   35   40   95
# 192  100   40   80   80

# %% [markdown]
# ### `방법3`:[],iloc,loc//map,lambda

# %% [markdown]
# #### []

# %%
df[list(map(lambda x,y : (x>90)& (y<50), df.att,df.rep))]
# Out:
#      att  rep  mid  fin
# 1     95   30   60   10
# 12    95   35    0   25
# 48    95   45   35   80
# 56    95   25   95   90
# 78    95   45   90   35
# 107  100   30   60   65
# 112  100   35   70    0
# 113   95   45   55   65
# 163  100   25   10   20
# 174  100   40   40   15
# 176  100   30   70   70
# 184  100   30   30   85
# 190   95   35   40   95
# 192  100   40   80   80

# %%
df[map(lambda x,y: (x>90)&(y<50), df.att, df.rep)] # 이것은 불가능
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [161], in <cell line: 1>()
# ----> 1 df[map(lambda x,y: (x>90)&(y<50), df.att, df.rep)]
#
# File ~\anaconda3\envs\py39\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\envs\py39\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\envs\py39\lib\site-packages\pandas\core\indexes\base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([False,  True, False, False, False, False, False, False, False, False,\n       ...\n        True, False,  True, False, False, False, False, False, False, False],\n      dtype='object', length=200)] are in the [columns]"

# %% [markdown]
# #### iloc

# %%
df.iloc[list(map(lambda x,y: (x>90)&(y<50), df.att, df.rep))]
df.iloc[map(lambda x,y: (x>90)&(y<50), df.att, df.rep)]
# Out:
#      att  rep  mid  fin
# 1     95   30   60   10
# 12    95   35    0   25
# 48    95   45   35   80
# 56    95   25   95   90
# 78    95   45   90   35
# 107  100   30   60   65
# 112  100   35   70    0
# 113   95   45   55   65
# 163  100   25   10   20
# 174  100   40   40   15
# 176  100   30   70   70
# 184  100   30   30   85
# 190   95   35   40   95
# 192  100   40   80   80

# %%
# !!!! list화 하지 않아도 알아서 잘 받는다

# %% [markdown]
# #### loc

# %%
df.loc[list(map(lambda x,y: (x>90)&(y<50), df.att, df.rep))]
df.loc[map(lambda x,y: (x>90)&(y<50), df.att, df.rep)]
# Out:
#      att  rep  mid  fin
# 1     95   30   60   10
# 12    95   35    0   25
# 48    95   45   35   80
# 56    95   25   95   90
# 78    95   45   90   35
# 107  100   30   60   65
# 112  100   35   70    0
# 113   95   45   55   65
# 163  100   25   10   20
# 174  100   40   40   15
# 176  100   30   70   70
# 184  100   30   30   85
# 190   95   35   40   95
# 192  100   40   80   80

# %%
#!!!! loc도 굳이 리스트화 해줄 필요가 없다.

# %% [markdown]
# ## att > mean(att)

# %% [markdown]
# ### `방법1`: query를 이용

# %%
df.query('att> att.mean()')
# Out:
#      att  rep  mid  fin
# 1     95   30   60   10
# 4     80   60   55   70
# 8     95   55   65   90
# 9     90   25   95   50
# 11    95   60   25   55
# ..   ...  ...  ...  ...
# 184  100   30   30   85
# 190   95   35   40   95
# 192  100   40   80   80
# 197   85   85  100   10
# 198   80   65   35   60
#
# [95 rows x 4 columns]

# %% [markdown]
# ### `방법2`: [], iloc , loc

# %% [markdown]
# #### [] ***시리즈를 받을 수 있다.***

# %%
df[df.att > df.att.mean()]
# Out:
#      att  rep  mid  fin
# 1     95   30   60   10
# 4     80   60   55   70
# 8     95   55   65   90
# 9     90   25   95   50
# 11    95   60   25   55
# ..   ...  ...  ...  ...
# 184  100   30   30   85
# 190   95   35   40   95
# 192  100   40   80   80
# 197   85   85  100   10
# 198   80   65   35   60
#
# [95 rows x 4 columns]

# %%
df.att > df.att.mean() #series
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 195    False
# 196    False
# 197     True
# 198     True
# 199    False
# Name: att, Length: 200, dtype: bool

# %% [markdown]
# #### iloc

# %%
df.iloc[list(df.att > df.att.mean())]
# Out:
#      att  rep  mid  fin
# 1     95   30   60   10
# 4     80   60   55   70
# 8     95   55   65   90
# 9     90   25   95   50
# 11    95   60   25   55
# ..   ...  ...  ...  ...
# 184  100   30   30   85
# 190   95   35   40   95
# 192  100   40   80   80
# 197   85   85  100   10
# 198   80   65   35   60
#
# [95 rows x 4 columns]

# %% [markdown]
# #### iloc은 series를 받을 수 없다,

# %%
df.iloc[(df.att > df.att.mean())]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Input In [184], in <cell line: 1>()
# ----> 1 df.iloc[(df.att > df.att.mean())]
#
# File ~\anaconda3\envs\py39\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\envs\py39\lib\site-packages\pandas\core\indexing.py:1506, in _iLocIndexer._getitem_axis(self, key, axis)
#    1503     key = np.asarray(key)
#    1505 if com.is_bool_indexer(key):
# -> 1506     self._validate_key(key, axis)
#    1507     return self._getbool_axis(key, axis=axis)
#    1509 # a list of integers
#
# File ~\anaconda3\envs\py39\lib\site-packages\pandas\core\indexing.py:1347, in _iLocIndexer._validate_key(self, key, axis)
#    1345 if hasattr(key, "index") and isinstance(key.index, Index):
#    1346     if key.index.inferred_type == "integer":
# -> 1347         raise NotImplementedError(
#    1348             "iLocation based boolean "
#    1349             "indexing on an integer type "
#    1350             "is not available"
#    1351         )
#    1352     raise ValueError(
#    1353         "iLocation based boolean indexing cannot use "
#    1354         "an indexable as a mask"
#    1355     )
#    1356 return
#
# NotImplementedError: iLocation based boolean indexing on an integer type is not available

# %%
# iloc은 리스트 숫자리스트(불형)을 받아야 한다

# %%
(df.att > df.att.mean()) # 노노
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 195    False
# 196    False
# 197     True
# 198     True
# 199    False
# Name: att, Length: 200, dtype: bool

# %%
list((df.att > df.att.mean())) # 예스
# Out:
# [False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False]

# %% [markdown]
# #### loc

# %%
df.loc[df.att > df.att.mean()]
# Out:
#      att  rep  mid  fin
# 1     95   30   60   10
# 4     80   60   55   70
# 8     95   55   65   90
# 9     90   25   95   50
# 11    95   60   25   55
# ..   ...  ...  ...  ...
# 184  100   30   30   85
# 190   95   35   40   95
# 192  100   40   80   80
# 197   85   85  100   10
# 198   80   65   35   60
#
# [95 rows x 4 columns]

# %%
df.att > df.att.mean() #loc은 이런걸로 받을 수 있다,
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4       True
#        ...
# 195    False
# 196    False
# 197     True
# 198     True
# 199    False
# Name: att, Length: 200, dtype: bool

# %% [markdown]
# ### `방법3`: [],iloc,loc// map,lambda

# %% [markdown]
# #### []//lambda

# %%
df[list(map(lambda x: x> df.att.mean() , df.att))]
# Out:
#      att  rep  mid  fin
# 1     95   30   60   10
# 4     80   60   55   70
# 8     95   55   65   90
# 9     90   25   95   50
# 11    95   60   25   55
# ..   ...  ...  ...  ...
# 184  100   30   30   85
# 190   95   35   40   95
# 192  100   40   80   80
# 197   85   85  100   10
# 198   80   65   35   60
#
# [95 rows x 4 columns]

# %% [markdown]
# #### iloc//lambda,map

# %%
df.iloc[list(map(lambda x: x> df.att.mean(), df.att))]
df.iloc[map(lambda x: x>df.att.mean() , df.att)]
# Out:
#      att  rep  mid  fin
# 1     95   30   60   10
# 4     80   60   55   70
# 8     95   55   65   90
# 9     90   25   95   50
# 11    95   60   25   55
# ..   ...  ...  ...  ...
# 184  100   30   30   85
# 190   95   35   40   95
# 192  100   40   80   80
# 197   85   85  100   10
# 198   80   65   35   60
#
# [95 rows x 4 columns]

# %% [markdown]
# #### loc// lambda,map

# %%
df.loc[list(map(lambda x: x > df.att.mean(), df.att))]
df.loc[map(lambda x:x>df.att.mean(), df.att)]
# Out:
#      att  rep  mid  fin
# 1     95   30   60   10
# 4     80   60   55   70
# 8     95   55   65   90
# 9     90   25   95   50
# 11    95   60   25   55
# ..   ...  ...  ...  ...
# 184  100   30   30   85
# 190   95   35   40   95
# 192  100   40   80   80
# 197   85   85  100   10
# 198   80   65   35   60
#
# [95 rows x 4 columns]

# %%
df[:6]
# Out:
#    att  rep  mid  fin
# 0   65   45    0   10
# 1   95   30   60   10
# 2   65   85   15   20
# 3   55   35   35    5
# 4   80   60   55   70
# 5   75   40   75   85
